# %% [markdown]
# ### Ideas for Evaluation
# Main goal is creating a reliable and replicable system that can evaluate the LLM outputs/responses and also determine which prompts work better for our task compared to others.
#
# - LLM Judges
# - Check if XRIF Json is valid json
# - Response Quality
# - Try many different requests, add new locations, modify information relevant to locations?
# - Try running a large loop of requests all using the same prompt prefix, and see which ones do well and which ones don't. Can your eval function properly identify good vs bad outputs?
# - Build some skills/tool specs and test those
#
# add timing to tasks

# %% [markdown]
# ### Relevant LLM concepts to know
# - Skills / Function Calling (Cohere calls them Tools)
# https://docs.cohere.com/v2/docs/tools
# - Structured Outputs -> https://docs.cohere.com/v2/docs/structured-outputs
# - AI Agents
# - RAG -> Retrieval Augmented Generation

# %%
# %pip install -r requirements.in
# Out:
# Requirement already satisfied: numpy in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 1)) (2.2.3)
# Requirement already satisfied: pandas in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 2)) (2.2.3)
# Requirement already satisfied: matplotlib in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 3)) (3.10.1)
# Requirement already satisfied: haystack-ai in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 4)) (2.10.3)
# Requirement already satisfied: seaborn in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 6)) (1.6.1)
# Requirement already satisfied: transformers in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 7)) (4.49.0)
# Requirement already satisfied: torch in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 8)) (2.6.0)
# Requirement already satisfied: torchvision in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 9)) (0.21.0)
# Requirement already satisfied: cohere in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 10)) (5.14.0)
# Requirement already satisfied: openai in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 11)) (1.65.2)
# Requirement already satisfied: wandb in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 12)) (0.19.7)
# Requirement already satisfied: dotenv in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 13)) (0.9.9)
# Requirement already satisfied: tqdm in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from -r requirements.in (line 14)) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from pandas->-r requirements.in (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from pandas->-r requirements.in (line 2)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from pandas->-r requirements.in (line 2)) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.in (line 3)) (3.2.1)
# Requirement already satisfied: haystack-experimental in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (0.7.0)
# Requirement already satisfied: jinja2 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (3.1.5)
# Requirement already satisfied: jsonschema in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (4.23.0)
# Requirement already satisfied: lazy-imports in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (0.4.0)
# Requirement already satisfied: more-itertools in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (10.6.0)
# Requirement already satisfied: networkx in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (3.4.2)
# Requirement already satisfied: openapi-llm>=0.4.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (0.4.1)
# Requirement already satisfied: posthog<3.12.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (3.11.0)
# Requirement already satisfied: pydantic in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (2.10.6)
# Requirement already satisfied: pyyaml in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (6.0.2)
# Requirement already satisfied: requests in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from haystack-ai->-r requirements.in (line 4)) (4.12.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.in (line 6)) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.in (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.in (line 6)) (3.5.0)
# Requirement already satisfied: filelock in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from transformers->-r requirements.in (line 7)) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from transformers->-r requirements.in (line 7)) (0.29.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from transformers->-r requirements.in (line 7)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from transformers->-r requirements.in (line 7)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from transformers->-r requirements.in (line 7)) (0.5.3)
# Requirement already satisfied: fsspec in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from torch->-r requirements.in (line 8)) (2025.2.0)
# Requirement already satisfied: setuptools in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from torch->-r requirements.in (line 8)) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from torch->-r requirements.in (line 8)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch->-r requirements.in (line 8)) (1.3.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from cohere->-r requirements.in (line 10)) (1.10.0)
# Requirement already satisfied: httpx>=0.21.2 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from cohere->-r requirements.in (line 10)) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from cohere->-r requirements.in (line 10)) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from cohere->-r requirements.in (line 10)) (2.27.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from cohere->-r requirements.in (line 10)) (2.32.0.20250301)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from openai->-r requirements.in (line 11)) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from openai->-r requirements.in (line 11)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from openai->-r requirements.in (line 11)) (0.8.2)
# Requirement already satisfied: sniffio in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from openai->-r requirements.in (line 11)) (1.3.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (3.1.44)
# Requirement already satisfied: platformdirs in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (5.29.3)
# Requirement already satisfied: psutil>=5.0.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (7.0.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (2.22.0)
# Requirement already satisfied: setproctitle in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from wandb->-r requirements.in (line 12)) (1.3.5)
# Requirement already satisfied: python-dotenv in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from dotenv->-r requirements.in (line 13)) (1.0.1)
# Requirement already satisfied: idna>=2.8 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.in (line 11)) (3.10)
# Requirement already satisfied: six>=1.4.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.in (line 12)) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.in (line 12)) (4.0.12)
# Requirement already satisfied: certifi in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.21.2->cohere->-r requirements.in (line 10)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.21.2->cohere->-r requirements.in (line 10)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.21.2->cohere->-r requirements.in (line 10)) (0.14.0)
# Requirement already satisfied: aiohttp in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (3.11.13)
# Requirement already satisfied: jsonref in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (1.1.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from posthog<3.12.0->haystack-ai->-r requirements.in (line 4)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from posthog<3.12.0->haystack-ai->-r requirements.in (line 4)) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from pydantic->haystack-ai->-r requirements.in (line 4)) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from requests->haystack-ai->-r requirements.in (line 4)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from requests->haystack-ai->-r requirements.in (line 4)) (2.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from jinja2->haystack-ai->-r requirements.in (line 4)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from jsonschema->haystack-ai->-r requirements.in (line 4)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from jsonschema->haystack-ai->-r requirements.in (line 4)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from jsonschema->haystack-ai->-r requirements.in (line 4)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from jsonschema->haystack-ai->-r requirements.in (line 4)) (0.23.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.in (line 12)) (5.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from aiohttp->openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from aiohttp->openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from aiohttp->openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from aiohttp->openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from aiohttp->openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/amaankler/Documents/FYDP/cookbook/.venv/lib/python3.12/site-packages (from aiohttp->openapi-llm>=0.4.1->haystack-ai->-r requirements.in (line 4)) (1.18.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip freeze requirements.txt
# Out:
# aiohappyeyeballs==2.4.6
# aiohttp==3.11.13
# aiosignal==1.3.2
# annotated-types==0.7.0
# anyio==4.8.0
# appnope==0.1.4
# asttokens==3.0.0
# attrs==25.1.0
# backoff==2.2.1
# certifi==2025.1.31
# charset-normalizer==3.4.1
# click==8.1.8
# cohere==5.14.0
# comm==0.2.2
# contourpy==1.3.1
# cycler==0.12.1
# debugpy==1.8.12
# decorator==5.2.1
# distro==1.9.0
# docker-pycreds==0.4.0
# dotenv==0.9.9
# executing==2.2.0
# fastavro==1.10.0
# filelock==3.17.0
# fonttools==4.56.0
# frozenlist==1.5.0
# fsspec==2025.2.0
# gitdb==4.0.12
# GitPython==3.1.44
# h11==0.14.0
# haystack-ai==2.10.3
# haystack-experimental==0.7.0
# httpcore==1.0.7
# httpx==0.28.1
# httpx-sse==0.4.0
# huggingface-hub==0.29.1
# idna==3.10
# ipykernel==6.29.5
# ipython==9.0.1
# ipython_pygments_lexers==1.1.1
# jedi==0.19.2
# Jinja2==3.1.5
# jiter==0.8.2
# joblib==1.4.2
# jsonref==1.1.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# kiwisolver==1.4.8
# lazy_imports==0.4.0
# MarkupSafe==3.0.2
# matplotlib==3.10.1
# matplotlib-inline==0.1.7
# monotonic==1.6
# more-itertools==10.6.0
# mpmath==1.3.0
# multidict==6.1.0
# nest-asyncio==1.6.0
# networkx==3.4.2
# numpy==2.2.3
# openai==1.65.2
# openapi-llm==0.4.1
# packaging==24.2
# pandas==2.2.3
# parso==0.8.4
# pexpect==4.9.0
# pillow==11.1.0
# platformdirs==4.3.6
# posthog==3.11.0
# prompt_toolkit==3.0.50
# propcache==0.3.0
# protobuf==5.29.3
# psutil==7.0.0
# ptyprocess==0.7.0
# pure_eval==0.2.3
# pydantic==2.10.6
# pydantic_core==2.27.2
# Pygments==2.19.1
# pyparsing==3.2.1
# python-dateutil==2.9.0.post0
# python-dotenv==1.0.1
# pytz==2025.1
# PyYAML==6.0.2
# pyzmq==26.2.1
# referencing==0.36.2
# regex==2024.11.6
# requests==2.32.3
# rpds-py==0.23.1
# safetensors==0.5.3
# scikit-learn==1.6.1
# scipy==1.15.2
# seaborn==0.13.2
# sentry-sdk==2.22.0
# setproctitle==1.3.5
# setuptools==75.8.2
# six==1.17.0
# smmap==5.0.2
# sniffio==1.3.1
# stack-data==0.6.3
# sympy==1.13.1
# tenacity==9.0.0
# threadpoolctl==3.5.0
# tokenizers==0.21.0
# torch==2.6.0
# torchvision==0.21.0
# tornado==6.4.2
# tqdm==4.67.1
# traitlets==5.14.3
# transformers==4.49.0
# types-requests==2.32.0.20250301
# typing_extensions==4.12.2
# tzdata==2025.1
# urllib3==2.3.0
# wandb==0.19.7
# wcwidth==0.2.13
# yarl==1.18.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import cohere
import pandas as pd
import json
import os

# %%
COHERE_API_KEY = os.getenv("COHERE_API_KEY")

# %%
cohere_client = cohere.ClientV2(api_key=COHERE_API_KEY)

# %%
def prompt_cohere(prompt, model_name = "command-r-plus-08-2024"):
    global cohere_client
    response = cohere_client.chat(
        model=model_name,
        messages=[
            {
                "role" : "user",
                "content" : prompt
            }
        ],
        response_format={"type": "json_object"},
    )
    return response.message.content[0].text

# %%
prompt_prefix_1 = """
You control a robot that can navigate through a building based on a json instruction format,
you understand several waypoints that have been given to you before (you can use RAG to retrieve
what room numbers or waypoints correspond to which people or semantics).

Here are all the waypoints you have access to:
- E7 1st floor Elevators, floor: 1
- E7 North Entrance, floor: 1
- E7 East Entrance, floor: 1
- E7 South Entrance, floor: 1
- E7 Coffee and Donuts, floor: 1
- Outreach Classroom, floor: 1
- RoboHub Entrance, floor: 1
- Vending Machine, floor: 1
- Room 2106, floor: 2

Extra information:
- Room 2106 is Zach's office
- Coffee and Donuts is referred to as CnD

Prompt: Can you pick something up from Zach's office and drop it off at the RoboHub?

Answer:
{
    "goals": [
        {
            "name": "Room 2106",
            "floor": 1
        },
        {
            "name": "RoboHub Entrance",
            "floor": 1
        }
    ]
}

Prompt:
"""

# %%
waypoints_df = pd.read_csv("/Users/amaankler/Documents/FYDP/cookbook/experiments/datasets/uw_e7_floor1.csv")
waypoints_list_str = json.dumps(waypoints_df.to_dict(orient="records"), indent=4)

e7_xrif_with_actions_3 = """
# Role
You control a robot that can navigate through a building based on a json instruction format, you understand several waypoints that have been provided in your context.
Your goal is to interperate user's requests into this JSON instruction format.


# Context
Here are all the waypoints you have access to:
{waypoints_list}

Here are all the Functions you have access to:
Navigate, speak and wait


# Understanding user prompts
when you are asked to get something make sure you speak in the exact location that the item is procured.
if someone states their location  and you are requested to go perform a task go there after you recive the item they are requesting or performed the task they are requestion.
if a waypoint is not in the list that is given or not like a waypoint in that list say this location does not exist.


# Examples
Example Prompt: Can you pick something up from the c and d and drop it off at the RoboHub?

Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "C&D - Coffee Area",
                "x": 100,
                "y": 100,

            }}
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub Entrance",
                "x": 25,
                "y": 50,
            }}
        }}
    ]
}}

Example Prompt: Can you ask Zach for the keys he is at the robohub and drop it off at the ideas clinic? Wait for 10 seconds when you meet Zach so he can give you the keys.

Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub",
                "x": 100,
                "y": 100,
            }}
        }},
        {{
            "action": "speak",
            "input": "Hey Zach, Can you hand me the keys?"
        }},
        {{
            "action": "wait",
            "input": 10
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "Room 1427 - Ideas Clinic",
                "x": 25,
                "y": 75,
            }}
        }}
    ]
}}
Example Prompt: can you go to the dairy queen

Example Answer:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "This waypoint does not exist"
    }}
  ]
}}

Prompt: {{query}}
"""

final_prompt = e7_xrif_with_actions_3.format(
    waypoints_list=waypoints_list_str,)

# %%
waypoints_df = pd.read_csv("/Users/amaankler/Documents/FYDP/cookbook/experiments/datasets/uw_e7_floor1.csv")
waypoints_list_str = json.dumps(waypoints_df.to_dict(orient="records"), indent=4)

e7_xrif_with_actions_4 = """
# Role
You control a robot that navigates through a building using a JSON instruction format. You have access to several pre-defined waypoints and functions. Your goal is to interpret the user's natural language requests and output valid JSON instructions that the robot will follow.

# JSON Output Format
Each output must be valid JSON (following [RFC 8259](https://tools.ietf.org/html/rfc8259)) with the following structure:
{{
  "actions": [
    {{
      "action": "<action_type>",  // Must be one of: "navigate", "speak", "wait"
      "input": <value>  // For "navigate": an object with "name", "x", and "y"; for "speak": a string; for "wait": a number (in seconds)
    }},
    ...
  ]
}}
Ensure there are no trailing commas and all JSON rules are followed.

# Context
- Available Waypoints: {waypoints_list}
- Available Functions: Navigate, speak, and wait.

# Understanding User Prompts
- For requests to retrieve an item, ensure you navigate to the item's location, then speak if required, and then proceed to the destination.
- If a user specifies their current location and requests a task, complete the task and then move to the provided destination.
- If a waypoint mentioned is not in the provided list or does not match any known waypoint—even after attempting fuzzy matching—output an action with `"action": "speak"` and the input `"This waypoint does not exist"`.
- For ambiguous instructions or missing information (e.g., unclear sequence, invalid parameters), output a single "speak" action with an error message explaining the issue (e.g., "Invalid request: missing destination" or "Ambiguous waypoint provided").

# Handling Complex Commands
- Process commands in a left-to-right sequence unless explicitly stated otherwise.
- For commands that include multiple steps, output the actions in the order they should be executed.
- If multiple interpretations exist, choose the interpretation that minimizes backtracking.

# Supported Edge Cases
- **Unknown Waypoint:** If a waypoint is unknown, return:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "This waypoint does not exist"
    }}
  ]
}}
- **Invalid or Ambiguous Commands:** Return a single speak action with an error message.
- **Unsupported Actions:** If any function beyond "navigate", "speak", or "wait" is requested, return:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "Unsupported action requested"
    }}
  ]
}}

# Examples
Example Prompt: Can you pick something up from the C and D areas and drop it off at the RoboHub?
Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "C&D - Coffee Area",
                "x": 100,
                "y": 100
            }}
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub Entrance",
                "x": 25,
                "y": 50
            }}
        }}
    ]
}}

Example Prompt: Can you ask Zach for the keys? He is at the RoboHub. After receiving the keys, drop them off at the Ideas Clinic. Also, wait for 10 seconds when you meet Zach.
Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub",
                "x": 100,
                "y": 100
            }}
        }},
        {{
            "action": "speak",
            "input": "Hey Zach, can you hand me the keys?"
        }},
        {{
            "action": "wait",
            "input": 10
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "Room 1427 - Ideas Clinic",
                "x": 25,
                "y": 75
            }}
        }}
    ]
}}

Example Prompt: Please go to the unknown zone and then to the RoboHub.
Example Answer:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "Invalid request: 'unknown zone' is not a valid waypoint"
    }}
  ]
}}

Prompt: {{query}}
"""

e7_xrif_with_actions4 = e7_xrif_with_actions_4.format(
    waypoints_list=waypoints_list_str,
)

# %%
waypoints_df = pd.read_csv("/Users/amaankler/Documents/FYDP/cookbook/experiments/datasets/uw_e7_floor1.csv")
waypoints_list_str = json.dumps(waypoints_df.to_dict(orient="records"), indent=4)

e7_xrif_with_actions_5 = """
# Role
You control a robot that navigates through a building using a JSON instruction format. You have access to several pre-defined waypoints and functions. Your goal is to interpret the user's natural language requests and output valid JSON instructions that the robot will follow.

# JSON Output Format
Each output must be valid JSON (following [RFC 8259](https://tools.ietf.org/html/rfc8259)) with the following structure:
{{
  "actions": [
    {{
      "action": "<action_type>",  // Must be one of: "navigate", "speak", "wait"
      "input": <value>  // For "navigate": an object with "name", "x", and "y"; for "speak": a string; for "wait": a number (in seconds)
    }},
    ...
  ]
}}
Ensure there are no trailing commas and all JSON rules are followed.

# Context
- Available Waypoints: {waypoints_list}
- Available Functions: Navigate, speak, and wait.

# Understanding User Prompts
# Advanced Fuzzy Matching for Waypoints

When matching waypoint names from the user's input against the available list, follow these steps:

1. **Normalization:**
   Convert both the user's input and each waypoint name to lowercase.

2. **Extraneous Token Removal:**
   Remove tokens that likely represent building codes or non-essential identifiers. For instance, if a token contains both letters and digits and appears at the beginning of the input, discard it.

3. **Tokenization:**
   Split both the cleaned user input and each known waypoint name into individual words.

4. **Similarity Calculation:**
   For each known waypoint, assess the match by:
   - Checking if every token from the waypoint name appears in the user's input.
   - Alternatively, ensuring that a high percentage (e.g., 80% or more) of the tokens in the waypoint name are present in the input.
   - If there is aditional words infront or after the waypoint name for example "waterloo robohub" would match to the waypoint for "RoboHub" meaning if all of the words for a waypoint are in the prompt treat it as this waypoint. 
   - if "E7" or any other building code is before a waypoint name ignore when determining if it is a valid waypoint.
   - "E7 ideas clinic" is the same thing as " Ideas clinic" for waypoint selection and is therefore not unknowen.  
5. **Selection and Fallback:**
   - If a single waypoint meets or exceeds the similarity threshold, treat it as a match.
   - If multiple waypoints meet the criteria, select the one with the highest similarity score.
   - If no known waypoint meets the threshold, for similarity including having 80% or more of the same tokens or having the words of the waypoint name included in the prompt then only if this is not met output an action with `"action": "speak"` and the input `"This waypoint does not exist"`.


# Handling Complex Commands
- Process commands in a left-to-right sequence unless explicitly stated otherwise.
- For commands that include multiple steps, output the actions in the order they should be executed.
- If multiple interpretations exist, choose the interpretation that minimizes backtracking.

# Supported Edge Cases
- **Unknown Waypoint:** If a waypoint is unknown and you have checked for the **Similarity Calculation** and it is not meet the thresholds for a similar waypoint return:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "This waypoint does not exist"
    }}
  ]
}}
- **Invalid or Ambiguous Commands:** Return a single speak action with an error message.
- **Unsupported Actions:** If any function beyond "navigate", "speak", or "wait" is requested, return:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "Unsupported action requested"
    }}
  ]
}}

# Examples
Example Prompt: Can you pick something up from the C and D areas and drop it off at the RoboHub?
Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "C&D - Coffee Area",
                "x": 100,
                "y": 100
            }}
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub Entrance",
                "x": 25,
                "y": 50
            }}
        }}
    ]
}}

Example Prompt: Can you ask Zach for the keys? He is at the RoboHub. After receiving the keys, drop them off at the Ideas Clinic. Also, wait for 10 seconds when you meet Zach.
Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub",
                "x": 100,
                "y": 100
            }}
        }},
        {{
            "action": "speak",
            "input": "Hey Zach, can you hand me the keys?"
        }},
        {{
            "action": "wait",
            "input": 10
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "Room 1427 - Ideas Clinic",
                "x": 25,
                "y": 75
            }}
        }}
    ]
}}

Example Prompt: Please go to the unknown zone and then to the RoboHub.
Example Answer:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "Invalid request: 'unknown zone' is not a valid waypoint"
    }}
  ]
}}

Prompt: {{query}}
"""

e7_xrif_with_actions5 = e7_xrif_with_actions_5.format(
    waypoints_list=waypoints_list_str,
)

print (waypoints_list_str)

# %%
waypoints_df = pd.read_csv("/Users/amaankler/Documents/FYDP/cookbook/experiments/datasets/uw_e7_floor1.csv")
waypoints_list_str = json.dumps(waypoints_df.to_dict(orient="records"), indent=4)

e7_xrif_with_actions_6 = """
# Role
You control a robot that navigates through a building using a JSON instruction format. You have access to several pre-defined waypoints and functions. Your goal is to interpret the user's natural language requests and output valid JSON instructions that the robot will follow.

# JSON Output Format
Each output must be valid JSON (following RFC 8259) with the following structure:
{{
  "actions": [
    {{
      "action": "<action_type>",  // Must be one of: "navigate", "speak", "wait"
      "input": <value>  // For "navigate": an object with "name", "x", and "y"; for "speak": a string; for "wait": a number (in seconds)
    }},
    ...
  ]
}}
Ensure there are no trailing commas and all JSON rules are followed.

# Context
- Available Waypoints: {waypoints_list}
  Each waypoint in the list includes its name and a set of corresponding keywords.
- Available Functions: Navigate, speak, and wait.

# Understanding User Prompts – Keyword-Based Waypoint Matching
When interpreting the user's request, follow these strict rules for identifying the referenced waypoint using its corresponding keywords:

1. Ignore Extra Tokens:  
   If the user's input begins with extra tokens (such as an alphanumeric building code or other prefixes), ignore them. For example, treat "E7 ideas clinic" as "ideas clinic".

2. Keyword Matching:  
   Each available waypoint comes with a set of keywords. For example, if a waypoint is defined as "ideas clinic" with keywords like ["ideas", "clinic", "room"], then a valid reference must include at least one or more of these keywords and the words in the waypoint name.  
   - The input "ideas clinic" or "ideas room" should both match this waypoint because they include the core identifier "ideas".

3. Strict Match Requirement:  
   After ignoring extra tokens, if the remaining text does not contain any of the keywords or the words in the waypoint name for a given waypoint, or if more than one waypoint could be inferred without a clear winner, then the reference is considered invalid.  
   In other words, a waypoint is only valid if the cleaned input contains at least one of the defined keywords or the words in the waypoint name for that waypoint and clearly points to one single available waypoint.

4. Invalid Waypoint Response:  
   If you determine that none of the available waypoints meets the keyword match criteria, output the following error response:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "This waypoint does not exist"
    }}
  ]
}}

# Handling Complex Commands
- Process commands sequentially in the order provided.
- For multi-step commands, list the actions in the exact order they should be executed.
- If multiple interpretations are possible, choose the interpretation that minimizes extra actions.

# Supported Edge Cases
- Unknown Waypoint:  
  If, after ignoring extra tokens, the input does not include at least one of the corresponding keywords for any available waypoint, output:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "This waypoint does not exist"
    }}
  ]
}}
- Invalid or Ambiguous Commands:  
  Output a single "speak" action with a clear error message.
- Unsupported Actions:  
  If the request includes any function beyond "navigate", "speak", or "wait", output:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "Unsupported action requested"
    }}
  ]
}}

# Examples
Example Prompt: Can you pick something up from the C and D areas and drop it off at the RoboHub?
Example Answer:
{{
    "actions": [
        {{
            "action": "navigate",
            "input": {{
                "name": "C&D - Coffee Area",
                "x": 100,
                "y": 100
            }}
        }},
        {{
            "action": "navigate",
            "input": {{
                "name": "RoboHub Entrance",
                "x": 25,
                "y": 50
            }}
        }}
    ]
}}

Example Prompt: Can you ask Zach for the keys? He is at the RoboHub. After receiving the keys, drop them off at the Ideas Clinic. Also, wait for 10 seconds when you meet Zach.
Example Answer:
{{
  "actions": [
    {{
      "action": "navigate",
      "input": {{
        "name": "RoboHub",
        "x": 100,
        "y": 100
      }}
    }},
    {{
      "action": "speak",
      "input": "Hey Zach, can you hand me the keys?"
    }},
    {{
      "action": "wait",
      "input": 10
    }},
    {{
      "action": "navigate",
      "input": {{
        "name": "Room 1427 - Ideas Clinic",
        "x": 25,
        "y": 75
      }}
    }}
  ]
}}

Example Prompt: Please go to the unknown zone and then to the RoboHub.
Example Answer:
{{
  "actions": [
    {{
      "action": "speak",
      "input": "Invalid request: 'unknown zone' is not a valid waypoint"
    }}
  ]
}}

"""



e7_xrif_with_actions6 = e7_xrif_with_actions_6.format(
    waypoints_list=waypoints_list_str,
)

# %%
prompt_prefix_2 = """
You control a robot that can navigate through a building based on a json instruction format,
you understand several waypoints that have been given to you before (you can use RAG to retrieve
what room numbers or waypoints correspond to which people or semantics).

Here are all the waypoints you have access to:
- E7 1st floor Elevators, floor: 1, keywords = ["elevator"]
- E7 North Entrance, floor: 1, keywords = ["entrance"]
- E7 East Entrance, floor: 1, keywords = ["entrance"]
- E7 South Entrance, floor: 1, keywords = ["entrance"]
- E7 Coffee and Donuts, floor: 1, keywords = ["food and drink", "coffee"]
- Outreach Classroom, floor: 1, keywords = ["classroom"]
- RoboHub Entrance, floor: 1, keywords = ["workshop", "robots", "Brandon"]
- Vending Machine, floor: 1, keywords = ["food and drink"]
- Room 2106, floor: 2, keywords = ["office", "zach", "WEEF"]

Extra information:
- Room 2106 is Zach's office
- Coffee and Donuts is referred to as CnD

Prompt: Can you pick something up from Zach's office and drop it off at the RoboHub?

Answer:
{
    "goals": [
        {
            "name": "Room 2106",
            "keywords": ["office", "zach", "WEEF"],
            "floor": 1
        },
        {
            "name": "RoboHub Entrance",
            "keywords": ["workshop", "robots", "Brandon"]
            "floor": 1
        }
    ]
}

Prompt:
"""

# %%
experiments = [
    "Get me an energy drink, I'm in the RoboHub also I am not in the robohub",
    "go to the c and d and say can someone get me a jamacan patty wait 30 seconds then go to the robohub",
    "get me a coffee and go tell john at the south enterance to meet me at robohub in 20 min then meet me i'm in the robohub but before you go wait 30 seconds",
    "go to the robo hub then the ECE lounge",
]




def run_experiment(prefix, list_of_inputs):
    for input in list_of_inputs:
        print(f"Input: {input}")
        print(prompt_cohere(f"{prefix}{input}"))

# %%
prompts_df = pd.read_csv("/Users/amaankler/Documents/FYDP/cookbook/experiments/datasets/Datasets & Prompts - E7 Test Cases.csv")


prompts_df = prompts_df.dropna(subset=["Prompt"]).reset_index(drop=True)


sample_size = min(10, len(prompts_df))


random_prompts = prompts_df["Prompt"].sample(sample_size).tolist()


print(random_prompts)
# Out:
# ['"There\'s no good coffee here. Don\'t go to the C&D"', '"Robot, go to [[Silent Study]], say \'Silent Study\' in a calm voice, and wait for 15 minutes."', '"Take me to the E7 silent study."', '"Take me to the E7 silent study."', '"Go to the North Entrance and then proceed to the C&D - Main Entrance."', '"I wonder how many entrances there are to E7. Also, Go to the C&D"', '"Robot, navigate to [[C&D - Hot Food Area]], announce \'C&D Hot Food Area\' clearly, and wait until further instructions."', '"Take me to the E7 silent study."', '"I need to freshen up. Take me two Shower A, then Shower B. Wait 1 minute at Shower B, then we can go."', '"Robot, start at C&D - Snack Area and inspect for spills or trash. Then, proceed to C&D - Cold Drink Area and ensure all drinks are properly stocked. Next, move to the C&D - Pastry Area and check for expired products. After that, visit the C&D - Coffee Area to confirm cleanliness. Finally, go to the C&D - Hot Food Area and sanitize any open surfaces before returning to the base station."']

# %%
def evaluate_output_v1():
    """Ensure proper json xrif format and ensure prompt only contains relevant information"""
    pass

# %%
# TODO: Build some relevant Cohere Skills to call and then run experiments with them.

# %% [markdown]
# Experiment notes:
#  Cohere and GPT 4 dont understand E7 silent study as silent study

# %%
run_experiment(e7_xrif_with_actions6, random_prompts)
# Out:
# Input: "There's no good coffee here. Don't go to the C&D"
# {
#     "actions": [
#         {
#             "action": "speak",
#             "input": "This waypoint does not exist"
#         }
#     ]
# }
# Input: "Robot, go to [[Silent Study]], say 'Silent Study' in a calm voice, and wait for 15 minutes."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "Silent Study",
#         "x": 1443,
#         "y": 572
#       }
#     },
#     {
#       "action": "speak",
#       "input": "Silent Study"
#     },
#     {
#       "action": "wait",
#       "input": 900
#     }
#   ]
# }
# Input: "Take me to the E7 silent study."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "Silent Study",
#         "x": 1443,
#         "y": 572
#       }
#     }
#   ]
# }
# Input: "Take me to the E7 silent study."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "Silent Study",
#         "x": 1443,
#         "y": 572
#       }
#     }
#   ]
# }
# Input: "Go to the North Entrance and then proceed to the C&D - Main Entrance."
# {
#     "actions": [
#         {
#             "action": "navigate",
#             "input": {
#                 "name": "North Entrance",
#                 "x": 739,
#                 "y": 1250
#             }
#         },
#         {
#             "action": "navigate",
#             "input": {
#                 "name": "C&D - Main Entrance",
#                 "x": 1965,
#                 "y": 1132
#             }
#         }
#     ]
# }
# Input: "I wonder how many entrances there are to E7. Also, Go to the C&D"
# {
#   "actions": [
#     {
#       "action": "speak",
#       "input": "There are three entrances to E7: the North Entrance, the East Entrance, and the South Entrance."
#     },
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Main Entrance",
#         "x": 1965,
#         "y": 1132
#       }
#     }
#   ]
# }
# Input: "Robot, navigate to [[C&D - Hot Food Area]], announce 'C&D Hot Food Area' clearly, and wait until further instructions."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Hot Food Area",
#         "x": 2091,
#         "y": 1157
#       }
#     },
#     {
#       "action": "speak",
#       "input": "C&D Hot Food Area"
#     },
#     {
#       "action": "wait",
#       "input": null
#     }
#   ]
# }
# Input: "Take me to the E7 silent study."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "Silent Study",
#         "x": 1443,
#         "y": 572
#       }
#     }
#   ]
# }
# Input: "I need to freshen up. Take me two Shower A, then Shower B. Wait 1 minute at Shower B, then we can go."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "Shower A",
#         "x": 951,
#         "y": 616
#       }
#     },
#     {
#       "action": "navigate",
#       "input": {
#         "name": "Shower B",
#         "x": 827,
#         "y": 610
#       }
#     },
#     {
#       "action": "wait",
#       "input": 60
#     }
#   ]
# }
# Input: "Robot, start at C&D - Snack Area and inspect for spills or trash. Then, proceed to C&D - Cold Drink Area and ensure all drinks are properly stocked. Next, move to the C&D - Pastry Area and check for expired products. After that, visit the C&D - Coffee Area to confirm cleanliness. Finally, go to the C&D - Hot Food Area and sanitize any open surfaces before returning to the base station."
# {
#   "actions": [
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Snack Area",
#         "x": 2071,
#         "y": 1247
#       }
#     },
#     {
#       "action": "speak",
#       "input": "Inspecting for spills and trash."
#     },
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Cold Drink Area",
#         "x": 2005,
#         "y": 1277
#       }
#     },
#     {
#       "action": "speak",
#       "input": "Checking drink stock."
#     },
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Pastry Area",
#         "x": 2069,
#         "y": 1199
#       }
#     },
#     {
#       "action": "speak",
#       "input": "Checking for expired products."
#     },
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Coffee Area",
#         "x": 2227,
#         "y": 1169
#       }
#     },
#     {
#       "action": "speak",
#       "input": "Confirming cleanliness."
#     },
#     {
#       "action": "navigate",
#       "input": {
#         "name": "C&D - Hot Food Area",
#         "x": 2091,
#         "y": 1157
#       }
#     },
#     {
#       "action": "speak",
#       "input": "Sanitizing open surfaces."
#     }
#   ]
# }
